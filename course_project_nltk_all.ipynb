# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import json
from tqdm import tqdm_notebook
from sklearn.metrics import *
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split, RandomizedSearchCV, GridSearchCV
from sklearn.feature_extraction.text import TfidfVectorizer
# from xgboost import XGBClassifier
# from catboost import CatBoostClassifier
# from lightgbm import LGBMClassifier
import warnings
import time
import string # библиотека для работы со строками
import re
import nltk   # Natural Language Toolkit
from sklearn.pipeline import Pipeline
warnings.filterwarnings("ignore")

# %%
with open('comments_all.json', encoding = 'utf-8') as json_file:
    data = json.load(json_file)

# %%
print(len([x["type_comment"] for x in data if x["type_comment"] == 'bad']))
# Out:
# 88253

# %%
def custom_preprocessor(text):
    '''
    Make text lowercase, remove text in square brackets,remove links,remove special characters
    and remove words containing numbers.
    '''
    text = text.lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub("\\W"," ",text) # remove special chars
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)
    text = re.sub(' +', ' ', text)
    
    return text

# %%
print(set([x["type_comment"] for x in data]))
# Out:
# {'neutral', 'bad', 'good'}

# %%
num = 300 

print("movie: ",          data[num]["name_movie"], "\n")
print("comment: \n",      data[num]["text_comment"], "\n")
print("date: ",           data[num]["date_comment"], "\n")
print("type: ",           data[num]["type_comment"], "\n")
# Out:
# movie:  Академия смерти
#
# comment:
#  Это очень хороший военно-исторический фильм об атмосфере, царящей в закрытом специализированном учебном учреждении Третьего Рейха-учреждении, готовящем будущую элиту общества Великой Германии. Создателям фильма удалось полностью передать эту атмосферу. Будто ты сам очевидец тех событий-и на улице, и в торжественном актовом зале, и на учениях.
#
# Интересный уже сам по себе-ведь Третий Рейх был одним из самых ярких и сильных государств мира!
#
# Интересна линия отношений между подростками в этом фильме.
#
# Фридрих Ваймер - талантливый боксер из рабочего квартала, мечтающий о лучшей судьбе, мужественный и сильный, упрямый, амбициозный; поступил в элитную школу Рейха против воли отца-рабочего, по собственному желанию, потому что 'такого шанса больше не будет...'
#
# Альбрехт Штайн - тонкий, хрупкий, романтичный, грустный и мечтательный юноша-эстет, индивидуалист, очень чувствительный; поступил в академию против своей воли, по воле своего отца-гауляйтера, так как 'это дает определенные привилегии'.
#
# 'Противоположности сходятся...' Таких разных людей, выросших в совершенно разных условиях, с разными взглядами и воспитанием, иногда тянет друг к другу. Тем более, когда один-простой и сильный, другой-хрупкий и утонченный.
#
# Фридрих и Альбрехт сразу потянулись друг к другу-возможно, даже слишком сильно. 'Пробежал ток-и все...'
#
# Я не утверждаю, что между героями были какие-то любовные 'отношения'. Но это могло быть вполне вероятно-и держаться в тайне, поскольку в Третьем Рейхе такие отношения пресекались. Возможно, Фридрих и Альбрехт не только о себе и страшные истории из жизни гитлерюгенда друг другу рассказывали. 'Либо дождик, любо снег, либо было, либо нет'. Но они испытывали друг к другу сильную взаимную привязанность-это точно. Слишком сильная дружба... Видели бы вы, как они обнялись после драки, возникшей из-за столкновения взглядов, лежа на полу в ванной комнате. А если бы кто-то зашел-что бы он подумал, интересно?
#
# Альбрехту, в отличие от Фридриха, было тяжело в атмосфере Третьего Рейха и этого учебного заведения, потому что такие люди для него не приспособлены.
#
# 'Нам не нужны эстетствующие хлюпики'-так сказал его отец.
#
# Альбрехт не был 'хлюпиком', но он был очень упрям и был индивидуалистом. Он. как и многие подростки, пошел против системы и отца-и испугался трудностей.
#
# Альбрехт не мог видеть картину смерти-и свел счеты с собственной жизнью. Когда Альбрехт тонул, меня колотила истерика. Мне так и хотелось крикнуть: 'Чего ты этим добился?! Кому ты этим помог?!' Жизнь дана для того, чтобы жить и бороться, по крайней мере до времени-а не для того, чтобы лежать по ледяным озерам. Ну и поступил бы Альбрехт в СС-может быть, пережил бы войну. А то погиб во цвете лет.
#
# Кстати. Фридрих, вместо того чтобы биться на льду и ломать руки и плакать, мог бы преспокойно нырнуть за Альбрехтом-не тратить время на попытку разбить лед.
#
# Альбрехт не получил даже некролога в местной газете-в отличие от Зигфрида, которого похоронили с почестями. Но Зигфрид был героем, он своей смертью спас своих товарищей, а Альбрехт только Фридриху сделал больно. Самоубийство нигде не приветствуется.
#
# Альбрехт мог добиться своим поступком 'обратного эффекта'-Фридрих мог не 'расчувствоваться', а ожесточиться.
#
# Но все равно он мне симпатичнее Фридриха.
#
# Почему же не было ничего сказано о том, что случилось с Фридрихом после ухода из школы?
#
# Этот фильм заставляет задуматься...
#
# 9 из 10
#
# date:  22 марта 2009 | 17:13
#
# type:  good

# %%
# загружаем список стоп-слов для русского
nltk.download('stopwords')
stop_words = nltk.corpus.stopwords.words('russian')

# примеры стоп-слов
# stop_words[:10]
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\AlexandrGnusarev\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
word_tokenizer = nltk.WordPunctTokenizer()

# %%
dates = [str(x) for x in np.arange(0, 2022)]
def process_data(data):
    texts = []
    targets = []
    
    # поочередно проходим по всем новостям в списке
    for item in tqdm_notebook(data):
               
#         text_lower = item['text_comment'].lower() # приводим все слова к нижнему регистру
#         text_lower = ''.join(c for c in text_lower if c not in delSymbols)
        text_lower = custom_preprocessor(item['text_comment'])
        tokens     = word_tokenizer.tokenize(text_lower) #разбиваем екст на слова
        
        # удаляем пунктуацию и стоп-слова
        tokens = [word for word in tokens if (word not in string.punctuation and word not in stop_words and word not in dates)]
        
        texts.append(tokens) # добавляем в предобработанный список
    
    return texts

# %%
# запускаем нашу предобработку
y = [item['type_comment'] for item in data]
texts = process_data(data)
# Out:
#   0%|          | 0/264759 [00:00<?, ?it/s]

# %%
# process_data(data[8]['type_comment'])

# %%
# example
i = 300
print("Label: ", y[i])
print("Tokens: ", texts[i][:20])
# Out:
# Label:  good
# Tokens:  ['это', 'очень', 'хороший', 'военно', 'исторический', 'фильм', 'атмосфере', 'царящей', 'закрытом', 'специализированном', 'учебном', 'учреждении', 'третьего', 'рейха', 'учреждении', 'готовящем', 'будущую', 'элиту', 'общества', 'великой']

# %%
# загружаем библиотеку для лемматизации
import pymorphy2 # Морфологический анализатор

# инициализируем лемматизатор :)
morph = pymorphy2.MorphAnalyzer()

# %%
# применяем лемматизацию ко всем текстам
for i in tqdm_notebook(range(len(texts))):           # tqdm_notebook создает шкалу прогресса :)
    text_lemmatized = [morph.parse(x)[0].normal_form for x in texts[i]] # применяем лемматизацию для каждого слова в тексте
    texts[i] = ' '.join(text_lemmatized)                # объединяем все слова в одну строку через пробел
# Out:
#   0%|          | 0/264759 [00:00<?, ?it/s]

# %%
# посмотрим на пример
i = 300
print("Label: ",   y[i])
print("Text: \n",  texts[i])
# Out:
# Label:  good
# Text:
#  это очень хороший военный исторический фильм атмосфера царить закрытый специализировать учебный учреждение третий рейх учреждение готовить будущий элита общество великий германия создатель фильм удаться полностью передать атмосфера очевидец тот событие улица торжественный актовый зал учение интересный третий рейх один самый яркий сильный государство мир интересный линия отношение подросток фильм фридрих ваймер талантливый боксёр рабочий квартал мечтать хороший судьба мужественный сильный упрямый амбициозный поступить элитный школа рейх против воля отец рабочий собственный желание такой шанс альбрехт штайна тонкий хрупкий романтичный грустный мечтательный юноша эстет индивидуалист очень чувствительный поступить академия против свой воля воля свой отец гауляйтер это давать определённый привилегия противоположность сходиться такой разный человек вырасти совершенно разный условие разный взгляд воспитание тянуть друг друг простой сильный хрупкий утончить фридрих альбрехт сразу потянуться друг друг возможно слишком сильно пробежать ток утверждать герой какой любовный отношение это мочь вполне вероятно держаться тайна поскольку третий рейх такой отношение пресекаться возможно фридрих альбрехт страшный история жизнь гитлерюгенд друг друг рассказывать либо дождик любо снег либо либо испытывать друг друг сильный взаимный привязанность это точно слишком сильный дружба видеть обняться драка возникнуть столкновение взгляд лёжа пол ванная комната зайти подумать интересно альбрехт отличие фридрих тяжело атмосфера третий рейх учебный заведение такой человек приспособить мы нужный эстетствовать хлюпик сказать отец альбрехт хлюпик очень упрямый индивидуалист многие подросток пойти против система отец испугаться трудность альбрехт мочь видеть картина смерть свести счёты собственный жизнь альбрехт тонуть колотить истерика хотеться крикнуть это добиться кто это помочь жизнь дать жить бороться крайний мера время лежать ледяной озёры поступить альбрехт сс пережить война погибнуть цвет год кстати фридрих вместо биться лёд ломать рука плакать мочь преспокойно нырнуть альбрехт тратить время попытка разбить лёд альбрехт получить некролог местный газета отличие зигфрид который похоронить почесть зигфрид герой свой смерть спасти свой товарищ альбрехт фридрих сделать больно самоубийство нигде приветствоваться альбрехт мочь добиться свой поступок обратный эффект фридрих мочь расчувствоваться ожесточиться равно симпатичный фридрих почему сказать случиться фридрих уход школа фильм заставлять задуматься

# %%
myfile = open('text_lemmatized_all.txt', mode='wt', encoding='utf-8')

for lines in texts:
    myfile.write(lines + '\n')
myfile.close
# Out:
# <function TextIOWrapper.close()>

# %%
# Функция для кодирования лейблов
def label2num(y):
    if y == 'good':
        return 1
    if y == 'bad':
        return -1
    if y == 'neutral':
        return 0

encoded_y = [label2num(yy) for yy in y]

# %%
from sklearn.model_selection import train_test_split
train_texts, test_texts, train_y, test_y = train_test_split(texts, encoded_y, test_size=0.2, random_state=42, stratify = y)

# %%
vectorizer = TfidfVectorizer(max_df = 0.7,
            max_features = 194,
            min_df = 0.1,
            norm = 'l2',
            ngram_range=(1,1)) # возмем топ 200 слов
# vectorizer.fit(train_texts)

# %%
train_X = vectorizer.fit_transform(train_texts)
test_X  = vectorizer.transform(test_texts)

# %%
from sklearn.linear_model import LogisticRegression
lg = LogisticRegression(C = 1.0, penalty = 'l2', solver = 'saga', random_state = 0)

lg.fit(train_X, train_y)

preds = lg.predict(test_X)

print(classification_report(test_y, preds))
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.60      0.64      0.62     17650
#            0       0.48      0.39      0.43     17651
#            1       0.59      0.65      0.62     17651
#
#     accuracy                           0.56     52952
#    macro avg       0.56      0.56      0.56     52952
# weighted avg       0.56      0.56      0.56     52952

# %%
confusion_matrix(test_y, preds)
# Out:
# array([[11363,  3812,  2475],
#        [ 5257,  6954,  5440],
#        [ 2348,  3761, 11542]], dtype=int64)

# %% [markdown]
# как видно из отчета точность на датасете со всеми тремя типа рецензий получилась довольно низкая.
# хуже всего модель справляется с нейтральными рецензиями - это видно и по classification_report и по confusion_matrix. модель путает их то с положительными, то с отрицательными.

# %%
x_tv=train_X.toarray()

imdb_data_len = x_tv.shape[:][0]
reviewLength = x_tv.shape[:][1]

positive_list = [0] * reviewLength
negative_list = [0] * reviewLength
neutral_list = [0] * reviewLength

positive_amount = 0
negative_amount = 0
neutral_amount = 0

def addVectorizedReviewRow(lst, reviewLst, reviewLength):
    for i in range(reviewLength):
        lst[i] = lst[i] + reviewLst[i]
    return lst

def normalizeVectorizedReviewRow(lst, reviewLength, amount):
    for i in range(reviewLength):
        lst[i] = lst[i] / amount
    return lst

for i in range(imdb_data_len):
    if y[i] == 'good':
        positive_list = addVectorizedReviewRow(positive_list, x_tv[i], reviewLength)
        positive_amount += 1
    elif y[i] == 'neutral':
        neutral_list = addVectorizedReviewRow(neutral_list,x_tv[i], reviewLength)
        neutral_amount += 1
    else:
        negative_list = addVectorizedReviewRow(negative_list,x_tv[i], reviewLength)
        negative_amount += 1
        
positive_list = normalizeVectorizedReviewRow(positive_list, reviewLength, positive_amount)
negative_list = normalizeVectorizedReviewRow(negative_list, reviewLength, negative_amount)
neutral_list = normalizeVectorizedReviewRow(neutral_list, reviewLength, neutral_amount)

# %%
bow=pd.DataFrame(positive_list, vectorizer.get_feature_names())
positive_text=bow.sort_values(by=0, ascending=False).iloc[:20]

font = {'size'   : 20}

plt.rc('font', **font)

fig, ax = plt.subplots(figsize=(20, 10))

ax.bar(positive_text.index.values, positive_text.T.iloc[:].values[0])
plt.xticks(rotation=75)
plt.xlabel("Stemmed Word")
plt.ylabel("Word_Frequency(Normalized)")
plt.show()

# %%
bow=pd.DataFrame(negative_list, vectorizer.get_feature_names())
negative_text=bow.sort_values(by=0, ascending=False).iloc[:20]

font = {'size'   : 20}

plt.rc('font', **font)

fig, ax = plt.subplots(figsize=(20, 10))

ax.bar(negative_text.index.values, negative_text.T.iloc[:].values[0])
plt.xticks(rotation=75)
plt.xlabel("Stemmed Word")
plt.ylabel("Word_Frequency(Normalized)")
plt.show()

# %%
bow=pd.DataFrame(neutral_list, vectorizer.get_feature_names())
neutral_text=bow.sort_values(by=0, ascending=False).iloc[:20]

font = {'size'   : 20}

plt.rc('font', **font)

fig, ax = plt.subplots(figsize=(20, 10))

ax.bar(neutral_text.index.values, neutral_text.T.iloc[:].values[0])
plt.xticks(rotation=75)
plt.xlabel("Stemmed Word")
plt.ylabel("Word_Frequency(Normalized)")
plt.show()

# %% [markdown]
# при этом список слов во всех типах рецензий достаточно похож
